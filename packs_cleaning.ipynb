# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy

# %%
packs_raw = pd.read_csv(r'data/packs.tsv', sep='\t', header=None, names=['pack_name', 'brand_all', 'piece_count_all', 'difficulty_all'])

# %%
packs_raw.head()
# Out:
#                                            pack_name       brand_all  \
# 0  Anne Belle Thompson The Mikado Anne Belle Thom...  Other-Hand-cut
# 1  Anthology Puzzles Alphonse Mucha La Plume Anth...             NaN
# 2  Anthology Puzzles Colorful Cat Anthology Puzzl...             NaN
# 3  Anthology Puzzles Framed American Gothic Antho...             NaN
# 4  Anthology Puzzles Over The Moon Anthology Puzz...             NaN
#
#   piece_count_all   difficulty_all
# 0         387,242  Average,Average
# 1         320,160  Average,Average
# 2         150,170  Average,Average
# 3         320,300  Average,Average
# 4         278,177      Hard,A-Easy

# %%
packs_raw.dtypes
# Out:
# pack_name          object
# brand_all          object
# piece_count_all    object
# difficulty_all     object
# dtype: object

# %%
packs_raw[packs_raw['pack_name'].isna()]
# Out:
# Empty DataFrame
# Columns: [pack_name, brand_all, piece_count_all, difficulty_all]
# Index: []

# %%
packs_raw['piece_count_all'].str.split(',', n=1, expand=True)
# Out:
#        0    1
# 0    387  242
# 1    320  160
# 2    150  170
# 3    320  300
# 4    278  177
# ..   ...  ...
# 904  364  207
# 905  442  170
# 906  262  314
# 907  158  205
# 908  460  364
#
# [909 rows x 2 columns]

# %% [markdown]
# Separate rows into
#
# {
#     pack_name,
#     brand_0,
#     brand_1,
#     brand_2,
#     piece_count_0,
#     piece_count_1,
#     piece_count_2,
#     difficulty_0,
#     difficulty_1,
#     difficulty_2
# }

# %%
# Split brands
brands_split = packs_raw['brand_all'].str.split(',', n=1, expand=True).rename(columns={0:'brand_0', 1:'brand_1'})
brands_split.head()
# Out:
#           brand_0 brand_1
# 0  Other-Hand-cut    None
# 1             NaN     NaN
# 2             NaN     NaN
# 3             NaN     NaN
# 4             NaN     NaN

# %%
# Split pieces
pieces_split = packs_raw['piece_count_all'].str.split(',', n=1, expand=True).rename(columns={0:'pieces_0', 1:'pieces_1'})
pieces_split.head()
# Out:
#   pieces_0 pieces_1
# 0      387      242
# 1      320      160
# 2      150      170
# 3      320      300
# 4      278      177

# %%
# Split difficulty
diff_split = packs_raw['difficulty_all'].str.split(',', n=1, expand=True).rename(columns={0:'diff_0', 1:'diff_1'})
diff_split.head()
# Out:
#     diff_0   diff_1
# 0  Average  Average
# 1  Average  Average
# 2  Average  Average
# 3  Average  Average
# 4     Hard   A-Easy

# %%
#test = packs_raw['pack_name'].map(lambda n: 1 if (n[-1] == ' ') else 2, na_action='ignore')

# %%
packs_split = packs_raw.join([brands_split, pieces_split, diff_split])
packs_split['num_puzzles'] = packs_raw['pack_name'].map(lambda n: 1 if (n[-1] == ' ') else 2, na_action='ignore')
packs_split.head()
# Out:
#                                            pack_name       brand_all  \
# 0  Anne Belle Thompson The Mikado Anne Belle Thom...  Other-Hand-cut
# 1  Anthology Puzzles Alphonse Mucha La Plume Anth...             NaN
# 2  Anthology Puzzles Colorful Cat Anthology Puzzl...             NaN
# 3  Anthology Puzzles Framed American Gothic Antho...             NaN
# 4  Anthology Puzzles Over The Moon Anthology Puzz...             NaN
#
#   piece_count_all   difficulty_all         brand_0 brand_1 pieces_0 pieces_1  \
# 0         387,242  Average,Average  Other-Hand-cut    None      387      242
# 1         320,160  Average,Average             NaN     NaN      320      160
# 2         150,170  Average,Average             NaN     NaN      150      170
# 3         320,300  Average,Average             NaN     NaN      320      300
# 4         278,177      Hard,A-Easy             NaN     NaN      278      177
#
#     diff_0   diff_1  num_puzzles
# 0  Average  Average            2
# 1  Average  Average            2
# 2  Average  Average            2
# 3  Average  Average            2
# 4     Hard   A-Easy            2

# %%
packs_split = packs_split.drop(['brand_all', 'piece_count_all', 'difficulty_all'], axis=1)
packs_split
# Out:
#                                              pack_name         brand_0  \
# 0    Anne Belle Thompson The Mikado Anne Belle Thom...  Other-Hand-cut
# 1    Anthology Puzzles Alphonse Mucha La Plume Anth...             NaN
# 2    Anthology Puzzles Colorful Cat Anthology Puzzl...             NaN
# 3    Anthology Puzzles Framed American Gothic Antho...             NaN
# 4    Anthology Puzzles Over The Moon Anthology Puzz...             NaN
# ..                                                 ...             ...
# 904  Artifact Puzzles Randal Spangler Fireside Fair...        Artifact
# 905  Smyth Puzzles Mola Madness TurtleTeasers Peaco...  Other-Hand-cut
# 906  Artifact Puzzles Haeckel Hummingbirds Artifact...        Artifact
# 907  Ecru Puzzles Allen Gilbert Cram Fishermans Cot...        Artifact
# 908  Artifact Puzzles Matt Lyon Monastery Artifact ...        Artifact
#
#     brand_1 pieces_0 pieces_1       diff_0       diff_1  num_puzzles
# 0      None      387      242      Average      Average            2
# 1       NaN      320      160      Average      Average            2
# 2       NaN      150      170      Average      Average            2
# 3       NaN      320      300      Average      Average            2
# 4       NaN      278      177         Hard       A-Easy            2
# ..      ...      ...      ...          ...          ...          ...
# 904    None      364      207       A-Easy      Average            2
# 905    None      442      170  Really-Hard       A-Easy            2
# 906    None      262      314      Average         Hard            2
# 907    Ecru      158      205      Average         Hard            2
# 908    None      460      364  Really-Hard  Really-Hard            2
#
# [909 rows x 8 columns]

# %%
pack_puzzles = packs_raw['pack_name']

# %%
packs_split[packs_split.pack_name.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [pack_name, brand_0, brand_1, pieces_0, pieces_1, diff_0, diff_1, num_puzzles]
# Index: []

# %%
packs_split = packs_split.astype({'pieces_0': 'int64', 'pieces_1': 'int64'}, errors='ignore')

# %%
packs_split.head()
# Out:
#                                            pack_name         brand_0 brand_1  \
# 0  Anne Belle Thompson The Mikado Anne Belle Thom...  Other-Hand-cut    None
# 1  Anthology Puzzles Alphonse Mucha La Plume Anth...             NaN     NaN
# 2  Anthology Puzzles Colorful Cat Anthology Puzzl...             NaN     NaN
# 3  Anthology Puzzles Framed American Gothic Antho...             NaN     NaN
# 4  Anthology Puzzles Over The Moon Anthology Puzz...             NaN     NaN
#
#   pieces_0 pieces_1   diff_0   diff_1  num_puzzles
# 0      387      242  Average  Average            2
# 1      320      160  Average  Average            2
# 2      150      170  Average  Average            2
# 3      320      300  Average  Average            2
# 4      278      177     Hard   A-Easy            2

# %%
packs_split.to_csv(r'data/packs_clean.csv')

# %%
# Some rows straight up have nothing, drop these as there is nothing to be done
packs_filtered = packs_split.dropna(subset = ['brand_0', 'brand_1', 'pieces_0', 'pieces_1', 'diff_0', 'diff_1'], how='all')
packs_filtered.head()
# Out:
#                                            pack_name         brand_0 brand_1  \
# 0  Anne Belle Thompson The Mikado Anne Belle Thom...  Other-Hand-cut    None
# 1  Anthology Puzzles Alphonse Mucha La Plume Anth...             NaN     NaN
# 2  Anthology Puzzles Colorful Cat Anthology Puzzl...             NaN     NaN
# 3  Anthology Puzzles Framed American Gothic Antho...             NaN     NaN
# 4  Anthology Puzzles Over The Moon Anthology Puzz...             NaN     NaN
#
#   pieces_0 pieces_1   diff_0   diff_1  num_puzzles
# 0      387      242  Average  Average            2
# 1      320      160  Average  Average            2
# 2      150      170  Average  Average            2
# 3      320      300  Average  Average            2
# 4      278      177     Hard   A-Easy            2

# %%
packs_filtered[(packs_filtered.num_puzzles == 1) & (packs_filtered.brand_1.notna() | packs_filtered.pieces_1.notna())]
# Out:
#                                              pack_name          brand_0  \
# 45   Artifact Puzzles Roch Urbaniak Floating Town A...         Artifact
# 77            DaVici Puzzles Awakening DaVici Puzzles            DaVici
# 99   Davici Puzzles Photo Album Ecru Puzzles Sunny ...           DaVici
# 127  Inside Adventure Odilon Redon Butterflies Peac...  Other-Laser-cut
# 203  Liberty Puzzles Jane Tattersfield Peacock And ...          Liberty
# 272  Liberty Puzzles Sue Coccia Great Horned Owl Li...          Liberty
# 376  Palmaris Puzzles Susan Schroder Portal Swift O...              NaN
# 486  Wentworth Puzzles Fractal Geometry Wentworth P...        Wentworth
# 566  Artifact Puzzles Sorolla Valencia Artifact Puz...         Artifact
# 606  Nautilus Puzzles Liberty Eugene Delacroix Libe...          Liberty
# 639  Whimsy Puzzles Christy Moeller Cat Girl Hartma...  Other-Laser-cut
# 651  Artifact Puzzles Iwona Lifsches Santa Claus De...         Artifact
# 676  Artifact Puzzles Edward Hopper Chop Suey Artif...         Artifact
# 716  Mr. Gogo Puzzles Just A Challenge Mr. Gogo Puz...   Other-Hand-cut
# 846  Artifact Puzzles Seurat Grande Jatte Artifact ...         Artifact
# 874  Ecru Puzzles William Penhallow Henderson Lucer...         Artifact
#
#              brand_1 pieces_0 pieces_1       diff_0   diff_1  num_puzzles
# 45              None      228      216       A-Easy   A-Easy            1
# 77              None      450      280      Average  Average            1
# 99              Ecru      600      369      Average  Average            1
# 127             None      604      260      Average  Average            1
# 203  Other-Laser-cut      508      400      Average  Average            1
# 272             None      372      510      Average  Average            1
# 376              NaN      470      200      Average  Average            1
# 486             None      229      504  Really-Hard  Average            1
# 566             None      150      156       A-Easy     Hard            1
# 606         Nautilus      466     None         Hard  Average            1
# 639             None      450      209      Average  Average            1
# 651        Wentworth      158      250       A-Easy     Hard            1
# 676             None      346      374       A-Easy   A-Easy            1
# 716             None      264      269         Hard  Average            1
# 846             None      428      338  Really-Hard     Hard            1
# 874             Ecru      385      411       A-Easy   A-Easy            1

# %%
# Some 1 puzzle packs have a second number for pieces, this seems to be legit, updating to be 2 puzzle packs
packs_filtered.loc[((packs_filtered.num_puzzles == 1) & (packs_filtered.pieces_1.notna())), 'num_puzzles'] = 2

# %%
# Out:
# pack_name      Artifact Puzzles Tyukanov Purgatory Artifact P...
# brand_0                                                 Artifact
# brand_1                                                     None
# pieces_0                                                     659
# pieces_1                                                      80
# diff_0                                                      Hard
# diff_1                                                      Hard
# num_puzzles                                                    2
# Name: 50, dtype: object

# %%
packs_filtered[(packs_filtered.pieces_1.isna()) & (packs_filtered.num_puzzles == 2)]
# Out:
#                                              pack_name    brand_0  \
# 9    Artifact Puzzles Bee Eater Artifact Puzzles Ke...   Artifact
# 33   Artifact Puzzles Kristian Adams Snoozies Artif...   Artifact
# 133  Liberty Puzzle Konstatin Gorbatov A Winters Da...       Ecru
# 142  Liberty Puzzles Alphonse Mucha La Danse Libert...    Liberty
# 243  Liberty Puzzles Muktair Oladoja Lovers Ecru Pu...       Ecru
# 248  Liberty Puzzles Paris Air France Ecru Puzzles ...       Ecru
# 389  Snowflake Puzzles Colorful Twirly-ques Ecru Pu...       Ecru
# 427  Stave Puzzles My Special Tea Wentworth Puzzles...      Stave
# 440  Turtle Teasers The Paradise of the Medicine Bu...        NaN
# 456  Wentworth Puzzles Beautiful Victorian Day Whim...  Wentworth
# 652  Artifact Puzzles Paul Ranson Flowers Double Si...   Artifact
# 672  Artifact Puzzles Allie Sullberg Lets Dance Art...   Artifact
# 673  Artifact Puzzles Alceste Campriani Pappagalli ...   Artifact
# 686  Ecru Puzzles Allen Gilbert Cram Fishermans Cot...   Artifact
# 690  Ecru Puzzles Kawase Hasui Fall Ecru Puzzles Ho...       Ecru
#
#              brand_1 pieces_0 pieces_1       diff_0   diff_1  num_puzzles
# 9               None      439     None         Hard   A-Easy            2
# 33              None      413     None      Average  Average            2
# 133          Liberty      527     None         Hard  Average            2
# 142             None      258     None      Average     Hard            2
# 243          Liberty      504     None      Average  Average            2
# 248          Liberty      483     None         Hard   A-Easy            2
# 389   Other-Hand-cut      500     None      Average   A-Easy            2
# 427        Wentworth       75     None  Really-Hard   A-Easy            2
# 440              NaN      158     None      Average  Average            2
# 456  Other-Laser-cut      450     None      Average  Average            2
# 652             None       79     None         Hard     Hard            2
# 672             None      367     None       A-Easy  Average            2
# 673             None      201     None      Average  Average            2
# 686             Ecru      158     None      Average  Average            2
# 690             None      NaN      NaN       A-Easy  Average            2

# %%
packs_filtered.loc[672]['pack_name']
# Out:
# 'Artifact Puzzles Allie Sullberg Lets Dance Artifact Puzzles Kevin Sloan Welcome to the Wilderness'

# %%
# Could just drop the 2 puzzle rows that don't have full piece info?
packs_filtered_2 = packs_filtered[~((packs_filtered.num_puzzles == 2) & (packs_filtered.pieces_1.isna()))]

# %%
packs_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 821 entries, 0 to 908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   pack_name    821 non-null    object
#  1   brand_0      792 non-null    object
#  2   brand_1      112 non-null    object
#  3   pieces_0     817 non-null    object
#  4   pieces_1     654 non-null    object
#  5   diff_0       821 non-null    object
#  6   diff_1       821 non-null    object
#  7   num_puzzles  821 non-null    int64
# dtypes: int64(1), object(7)
# memory usage: 90.0+ KB

# %%
packs_filtered_2
# Out:
#                                              pack_name         brand_0  \
# 0    Anne Belle Thompson The Mikado Anne Belle Thom...  Other-Hand-cut
# 1    Anthology Puzzles Alphonse Mucha La Plume Anth...             NaN
# 2    Anthology Puzzles Colorful Cat Anthology Puzzl...             NaN
# 3    Anthology Puzzles Framed American Gothic Antho...             NaN
# 4    Anthology Puzzles Over The Moon Anthology Puzz...             NaN
# ..                                                 ...             ...
# 904  Artifact Puzzles Randal Spangler Fireside Fair...        Artifact
# 905  Smyth Puzzles Mola Madness TurtleTeasers Peaco...  Other-Hand-cut
# 906  Artifact Puzzles Haeckel Hummingbirds Artifact...        Artifact
# 907  Ecru Puzzles Allen Gilbert Cram Fishermans Cot...        Artifact
# 908  Artifact Puzzles Matt Lyon Monastery Artifact ...        Artifact
#
#     brand_1 pieces_0 pieces_1       diff_0       diff_1  num_puzzles
# 0      None      387      242      Average      Average            2
# 1       NaN      320      160      Average      Average            2
# 2       NaN      150      170      Average      Average            2
# 3       NaN      320      300      Average      Average            2
# 4       NaN      278      177         Hard       A-Easy            2
# ..      ...      ...      ...          ...          ...          ...
# 904    None      364      207       A-Easy      Average            2
# 905    None      442      170  Really-Hard       A-Easy            2
# 906    None      262      314      Average         Hard            2
# 907    Ecru      158      205      Average         Hard            2
# 908    None      460      364  Really-Hard  Really-Hard            2
#
# [806 rows x 8 columns]

# %%
packs_filtered_2.to_csv(r'data/packs_cleaned_dropna.csv')
